# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df_drop = application_df.drop('EIN', axis=1)
application_df_clean = application_df_drop.drop('NAME', axis=1)
application_df_clean.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
unique_values_1 = application_df_clean['APPLICATION_TYPE'].unique()
print(unique_values_1)
print(17)

unique_values_2 = application_df_clean['AFFILIATION'].unique()
print(unique_values_2)
print(6)

unique_values_3 = application_df_clean['CLASSIFICATION'].unique()
print(unique_values_3)
print(71)

unique_values_4 = application_df_clean['USE_CASE'].unique()
print(unique_values_4)
print(5)

unique_values_5 = application_df_clean['ORGANIZATION'].unique()
print(unique_values_5)
print(4)

unique_values_6 = application_df_clean['STATUS'].unique()
print(unique_values_6)
print(2)

unique_values_7 = application_df_clean['INCOME_AMT'].unique()
print(unique_values_7)
print(9)

unique_values_8 = application_df_clean['SPECIAL_CONSIDERATIONS'].unique()
print(unique_values_8)
print(2)

unique_values_9 = application_df_clean['ASK_AMT'].unique()
print(unique_values_9)
print('All')

unique_values_10 = application_df_clean['IS_SUCCESSFUL'].unique()
print(unique_values_10)
print(2)
# Out:
# ['T10' 'T3' 'T5' 'T7' 'T4' 'T6' 'T2' 'T9' 'T19' 'T8' 'T13' 'T12' 'T29'
#  'T25' 'T14' 'T17' 'T15']
# 17
# ['Independent' 'CompanySponsored' 'Family/Parent' 'National' 'Regional'
#  'Other']
# 6
# ['C1000' 'C2000' 'C3000' 'C1200' 'C2700' 'C7000' 'C7200' 'C1700' 'C4000'
#  'C7100' 'C2800' 'C6000' 'C2100' 'C1238' 'C5000' 'C7120' 'C1800' 'C4100'
#  'C1400' 'C1270' 'C2300' 'C8200' 'C1500' 'C7210' 'C1300' 'C1230' 'C1280'
#  'C1240' 'C2710' 'C2561' 'C1250' 'C8000' 'C1245' 'C1260' 'C1235' 'C1720'
#  'C1257' 'C4500' 'C2400' 'C8210' 'C1600' 'C1278' 'C1237' 'C4120' 'C2170'
#  'C1728' 'C1732' 'C2380' 'C1283' 'C1570' 'C2500' 'C1267' 'C3700' 'C1580'
#  'C2570' 'C1256' 'C1236' 'C1234' 'C1246' 'C2190' 'C4200' 'C0' 'C3200'
#  'C5200' 'C1370' 'C2600' 'C1248' 'C6100' 'C1820' 'C1900' 'C2150']
# 71
# ['ProductDev' 'Preservation' 'Heathcare' 'CommunityServ' 'Other']
# 5
# ['Association' 'Co-operative' 'Trust' 'Corporation']
# 4
# [1 0]
# 2
# ...

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
T2 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T2'].count()
print("T2:", T2[0])

T3 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T3'].count()
print("T3:", T3[0])

T4 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T4'].count()
print("T4:", T4[0])

T5 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T5'].count()
print("T5:", T5[0])

T6 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T6'].count()
print("T6:", T6[0])

T7 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T7'].count()
print("T7:", T7[0])

T8 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T8'].count()
print("T8:", T8[0])

T9 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T9'].count()
print("T9:", T9[0])

T10 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T10'].count()
print("T10:", T10[0])

T12 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T12'].count()
print("T12:", T12[0])

T13 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T13'].count()
print("T13:", T13[0])

T14 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T14'].count()
print("T14:", T14[0])

T15 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T15'].count()
print("T15:", T15[0])

T17 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T17'].count()
print("T17:", T17[0])

T19 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T19'].count()
print("T19:", T19[0])

T25 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T25'].count()
print("T25:", T25[0])

T29 = application_df_clean[application_df_clean['APPLICATION_TYPE'] == 'T29'].count()
print("T29:", T29[0])
# Out:
# T2: 16
# T3: 27037
# T4: 1542
# T5: 1173
# T6: 1216
# T7: 725
# T8: 737
# T9: 156
# T10: 528
# T12: 27
# T13: 66
# T14: 3
# T15: 2
# T17: 1
# T19: 1065
# T25: 3
# T29: 2

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T2', 'T9', 'T12', 'T13', 'T14', 'T15', 'T17', 'T25', 'T29']

# Replace in dataframe
for app in application_types_to_replace:
    application_df_clean['APPLICATION_TYPE'] = application_df_clean['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df_clean['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
application_df_clean['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ['C2700','C7000','C7200','C1700','C4000','C7100','C2800','C6000','C1238',
                              'C5000','C7120','C1800','C4100','C1400','C1270','C2300','C8200','C1500',
                              'C7210','C1300','C1230','C1280','C1240','C2710','C2561','C1250','C8000',
                              'C1245','C1260','C1235','C1720','C1257','C4500','C2400','C8210','C1600',
                              'C1278','C1237','C4120','C2170','C1728','C1732','C2380','C1283','C1570',
                              'C2500','C1267','C3700','C1580','C2570','C1256','C1236','C1234','C1246',
                              'C2190','C4200','C0','C3200','C5200','C1370','C2600','C1248','C6100',
                              'C1820','C1900','C2150', 'C5000', 'C1500', 'C1278']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df_clean['CLASSIFICATION'] = application_df_clean['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df_clean['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
pd.get_dummies(application_df_clean)
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                   False
# 1           1    108590              1                   False
# 2           1      5000              0                   False
# 3           1      6692              1                   False
# 4           1    142590              1                   False
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                   False
# 34295       1      5000              0                   False
# 34296       1      5000              0                   False
# 34297       1      5000              1                   False
# 34298       1  36500179              0                   False
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                      True                 False                False
# ...

# %%
# Split our preprocessed data into our features and target arrays
application_df_clean

# Split the preprocessed data into a training and testing dataset
# Use sklearn to split dataset

import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl
import tensorflow as tf
from sklearn.datasets import make_moons

# Creating dummy nonlinear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# Creating a DataFrame to plot the nonlinear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Check the structure of the model
nn.summary()
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3720 - loss: 0.8173
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3086 - loss: 0.7966
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - accuracy: 0.2642 - loss: 0.7833
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 0.2917 - loss: 0.7764
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3009 - loss: 0.7715
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.3051 - loss: 0.7645
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3114 - loss: 0.7504
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - accuracy: 0.3283 - loss: 0.7485
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 0.3322 - loss: 0.7449
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 0.3053 - loss: 0.7371
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - accuracy: 0.3177 - loss: 0.7258
# ...

# %%
# Compile the model
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - 14ms/step - accuracy: 0.8000 - loss: 0.4634
# Loss: 0.46335092186927795, Accuracy: 0.800000011920929

# %%
# Train the model
nn = tf.keras.models.Sequential()
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)
nn.summary()
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8169 - loss: 0.4206
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.8184 - loss: 0.4211
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.8104 - loss: 0.4225
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.8050 - loss: 0.4228
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.8175 - loss: 0.4129
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 0.8376 - loss: 0.3849
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.8107 - loss: 0.4145
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - accuracy: 0.8260 - loss: 0.4055
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.8267 - loss: 0.3904
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - accuracy: 0.8451 - loss: 0.3850
# Epoch 11/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Export our model to HDF5 file
fit_model.save('AlphabetSoupCharity_Optimization.h5')
